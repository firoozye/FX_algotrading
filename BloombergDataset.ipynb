# %%
import datetime

#import dask.dataframe as dd
import numpy as np
import pandas as pd
from xbbg import blp

# %%
API_TASKS = {
'us.equities.data':{
    'instruments':[
        'SPX Index'
    ],
    'fields':[
        'PX_LAST',
        'PX_BID',
        'PX_ASK',
        'PX_MID',
        'PX_LOW',
        'PX_HIGH']
    },
    
    
'uk.equities.data':{
    'instruments':[
        'GBPUSD Curncy',
        'UKX Index',
    ],
    'fields':[
        'PX_LAST',
        'PX_BID',
        'PX_ASK',
        'PX_MID',
        'PX_LOW',
        'PX_HIGH']
    },
'jp.equities.data':{
    'instruments':[
        'JPYUSD Curncy',
        'NKY Index',
    ],
    'fields':[
        'PX_LAST',
        'PX_BID',
        'PX_ASK',
        'PX_MID',
        'PX_LOW',
        'PX_HIGH']
    },
'eu.equities.data':{
    'instruments':[
        'EURUSD Curncy',
        'SX5E Index',
        'CAC Index',
        'DAX Index',
        'IBEX Index',
        'FTSEMIB Index',      
    ],
    'fields':[
        'PX_LAST',
        'PX_BID',
        'PX_ASK',
        'PX_MID',
        'PX_LOW',
        'PX_HIGH']
    },
'us.economics.data':{
    'instruments':[
    'NFP TCH Index',
    'INJCJC Index',
    'FDTR Index',
    'CPI CHNG Index',
    'GDP CQOQ Index',
    'NAPMPMI Index',
    'CONSSENT Index',
    'CPI YOY Index',
    'RSTAMOM Index',
    'CONCCONF Index',
    'DGNOCHNG Index',
    'MBAVCHNG Index',
    'MPMIUSMA Index',
    'NHSLTOT Index',
    'USURTOT Index',
    'NHSPSTOT Index',
    'IP CHNG Index',
    'ADP CHNG Index',
    'FDIDFDMO Index',
    'ETSLTOTL Index',
    'PITLCHNG Index',
    'PCE CRCH Index',
    'TMNOCHNG Index',
    'USTBTOT Index',
    'EMPRGBCI Index',
    'LEI CHNG Index',
    'CHPMINDX Index',
    'MWINCHNG Index',
    'NAPMNMI Index',
    'CNSTTMOM Index',
    'OUTFGAF Index',
    'CPUPXCHG Index',
    'GDP PIQQ Index',
    'IMP1CHNG Index',
    'USPHTMOM Index',
    'ECI SA% Index',
    'DGNOXTCH Index',
    'FDDSSD Index',
    'NAPMPRIC Index',
    'USCABAL Index',
    'RCHSINDX Index',
    'MPMIUSSA Index',
    'MPMIUSCA Index',
    'FRNTTOTL Index',
    'USMMMNCH Index',
    'FDIUFDYO Index',
    'INJCSP Index',
    'HPIMMOM% Index',
    'FDIDSGMO Index',
    'GDPCTOT% Index',
    'GDPCPCEC Index',
    'FDIUSGYO Index',
    'CPI XYOY Index',
    'DFEDGBA Index',
    'RSTAXMOM Index',
    'FRNTTNET Index',
    'CFNAI Index',
    'NHSPATOT Index',
    'CPTICHNG Index'],       
'fields':[
    'ACTUAL_RELEASE',
    'FORECAST_STANDARD_DEVIATION',
    'BN_SURVEY_WEIGHTED_AVG',
    'BN_SURVEY_HIGH',
    'BN_SURVEY_LOW',
    'ECO_RELEASE_DT',
    'ECO_RELEASE_TIME'],
    },
'jp.economics.data':{
    'instruments':[
        'BOJDPBAL Index',
        'BOJDPRLT Index',
        'JBSIBCLA Index',
        'JBSIBCLM Index',
        'JBTARATE Index',
        'JCOMSHCF Index',
        'JCPNEFFE Index',
        'JCPTEFFE Index',
        'JFYFCPI1 Index',
        'JFYFCPI2 Index',
        'JFYFCPIC Index',
        'JFYFGDP1 Index',
        'JFYFGDP2 Index',
        'JFYFGDPC Index',
        'JGDFDEFY Index',
        'JGDOQOQ Index',
        'JGDPAGDP Index',
        'JGDPCIQ Index',
        'JGDPCNEX Index',
        'JGDPCPIN Index',
        'JGDPPCQ Index',
        'JGDPQGDP Index',
        'JHHSLERY Index',
        'JMNSM2Y Index',
        'JMNSM3Y Index',
        'JNBLBYOY Index',
        'JNBLENDA Index',
        'JNBPAB Index',
        'JNBPABA Index',
        'JNBPTRD Index',
        'JNC SALE Index',
        'JNCAPMOM Index',
        'JNCICCOI Index',
        'JNCICLEI Index',
        'JNCPIXFF Index',
        'JNCPIYOY Index',
        'JNCPT Index',
        'JNCPTXFF Index',
        'JNCRPYOY Index',
        'JNDSNYOY Index',
        'JNDSTYOY Index',
        'JNHSAN Index',
        'JNHSYOY Index',
        'JNIPMOM Index',
        'JNIPYOY Index',
        'JNLSUCRE Index',
        'JNLSUCTL Index',
        'JNMBMOBE Index',
        'JNMBYOY Index',
        'JNMOCHNG Index',
        'JNMOYOY Index',
        'JNMTOY Index',
        'JNNETYOY Index',
        'JNPIY Index',
        'JNRETMOM Index',
        'JNRSYOY Index',
        'JNSASYOY Index',
        'JNTBAL Index',
        'JNTBALA Index',
        'JNTBEXPY Index',
        'JNTBIMPY Index',
        'JNTEMFG Index',
        'JNTENMFG Index',
        'JNTIAMOM Index',
        'JNTSMFG Index',
        'JNTSNMFG Index',
        'JNUE Index',
        'JNVHSYOY Index',
        'JNVNIYOY Index',
        'JNVNYOYS Index',
        'JNWSDOM Index',
        'JNWSDYOY Index',
        'JPTFLMFG Index',
        'JPTFLNMF Index',
        'JPTFSMFG Index',
        'JPTFSNMF Index',
        'JSIABOND Index',
        'JSIASTCK Index',
        'JSIHBOND Index',
        'JSIHSTCK Index',
        'JTFIFILA Index',
        'JWCOOVSA Index',
        'JWEXOVSA Index',
        'MIKIMT07 Index',
        'MPMIJPCA Index',
        'MPMIJPMA Index',
        'MPMIJPSA Index'
    ],
    'fields': ['ACTUAL_RELEASE',
       'FORECAST_STANDARD_DEVIATION',
       'BN_SURVEY_WEIGHTED_AVG',
       'BN_SURVEY_HIGH',
       'BN_SURVEY_LOW',
       'ECO_RELEASE_DT',
       'ECO_RELEASE_TIME']
},   
'ez.economics.data':{
    'instruments':[
        'XTTBEZ Index',
        'XTSBEZ Index',
        'WCAR25 Y Index',
        'UMRTEMU Index',
        'SNTEEUGX Index',
        'RSWAEMUY Index',
        'RSSAEMUM Index',
        'NGVTEMUQ Index',
        'MPMIEZSA Index',
        'MPMIEZMA Index',
        'MPMIEZCA Index',
        'LNTNEMUY Index',
        'GRZEEUEX Index',
        'FCFNEMUQ Index',
        'EUSCEMU Index',
        'EUSATOTN Index',
        'EURR002W Index',
        'EUPPEMUY Index',
        'EUPPEMUM Index',
        'EUORMARG Index',
        'EUORDEPO Index',
        'EUITEMUM Index',
        'EUIPEMUY Index',
        'EUICEMU Index',
        'EUHNEMUQ Index',
        'EUGNEMUY Index',
        'EUGNEMUQ Index',
        'EUESEMU Index',
        'EUDBEURO Index',
        'EUCPTWDY Index',
        'EUCPTSAM Index',
        'EUCCEMU Index',
        'EMEMULYY Index',
        'EMEMULQQ Index',
        'ECMAM3YY Index',
        'ECIETDEA Index',
        'ECIENDEA Index',
        'ECCPEST Index',
        'ECCPEMUY Index',
        'ECCPEMUM Index',
        'CPEXEMUY Index',
    ],
        'fields': ['ACTUAL_RELEASE',
       'FORECAST_STANDARD_DEVIATION',
       'BN_SURVEY_WEIGHTED_AVG',
       'BN_SURVEY_HIGH',
       'BN_SURVEY_LOW',
       'ECO_RELEASE_DT',
       'ECO_RELEASE_TIME']
},
'uk.economics.data':{
    'instruments': [
    'UKBRBASE Index',
    'UKRPCJYR Index',
    'UKGRABIQ Index',
    'UKRPCJMR Index',
    'UKGRABIY Index',
    'UKHCA9IQ Index',
    'UKUEMOM Index',
    'UKIPIMOM Index',
    'MPMIGBMA Index',
    'UKUEILOR Index',
    'UKNBAAMM Index',
    'UKMPIMOM Index',
    'UKNBANYY Index',
    'UKMSVTVX Index',
    'UKRVINFM Index',
    'UKUER Index',
    'UKRVINFY Index',
    'UKRVAMOM Index',
    'MPMIGBXA Index',
    'MPMIGBSA Index',
    'UKRVAYOY Index',
    'UKIPIYOY Index',
    'UKTBTTBA Index',
    'UKRPMOM Index',
    'UKRPYOY Index',
    'MPMIGBCA Index',
    'UKPSJ5II Index',
    'UKTBALEE Index',
    'UKRPI Index',
    'UKMPIYOY Index',
    'UKCCI Index',
    'UKRMNAPM Index',
    'UKAWMWHO Index',
    'UKRXPBAL Index',
    'UKRMNAPY Index'],
        
    'fields': ['ACTUAL_RELEASE',
       'FORECAST_STANDARD_DEVIATION',
       'BN_SURVEY_WEIGHTED_AVG',
       'BN_SURVEY_HIGH',
       'BN_SURVEY_LOW',
       'ECO_RELEASE_DT',
       'ECO_RELEASE_TIME']
    },

'gbpusd.option.skew_kurt':{
    'instruments': [
        'GBPUSD1W Curncy',
        'GBPUSD1M Curncy',
        'GBPUSD3M Curncy',
        'GBPUSD6M Curncy',
        'GBPUSD1Y Curncy',
        'GBPUSDQ1W Curncy',
        'GBPUSDQ1M Curncy',
        'GBPUSDQ3M Curncy',
        'GBPUSDQ6M Curncy',
        'GBPUSDQ1Y Curncy',
        'GBPUSDK1W Curncy',
        'GBPUSDK1M Curncy',
        'GBPUSDK3M Curncy',
        'GBPUSDK6M Curncy',
        'GBPUSDK1Y Curncy'
        ],
    'fields': ['PX_MID']
},
'jpyusd.option.skew_kurt':{
    'instruments': [
        'USDJPY1W Curncy',
        'USDJPY1M Curncy',
        'USDJPY3M Curncy',
        'USDJPY6M Curncy',
        'USDJPY1Y Curncy',
        'USDJPYQ1W Curncy',
        'USDJPYQ1M Curncy',
        'USDJPYQ3M Curncy',
        'USDJPYQ6M Curncy',
        'USDJPYQ1Y Curncy',
        'USDJPYK1W Curncy',
        'USDJPYK1M Curncy',
        'USDJPYK3M Curncy',
        'USDJPYK6M Curncy',
        'USDJPYK1Y Curncy'
        ],
    'fields': ['PX_MID']
},
'eurusd.option.skew_kurt':{
    'instruments': [
        'EURUSD1W Curncy',
        'EURUSD1M Curncy',
        'EURUSD3M Curncy',
        'EURUSD6M Curncy',
        'EURUSD1Y Curncy',
        'EURUSDQ1W Curncy',
        'EURUSDQ1M Curncy',
        'EURUSDQ3M Curncy',
        'EURUSDQ6M Curncy',
        'EURUSDQ1Y Curncy',
        'EURUSDK1W Curncy',
        'EURUSDK1M Curncy',
        'EURUSDK3M Curncy',
        'EURUSDK6M Curncy',
        'EURUSDK1Y Curncy'
        ],
    'fields': ['PX_MID']
},
'usd_rates':{
    'instruments':[
    'G0025Z 3M BLC2 Curncy', #USD I25 Zero Rate 3M Currncy?
    'G0025Z 6M BLC2 Curncy',
    'G0025Z 1Y BLC2 Curncy',
    'G0025Z 2Y BLC2 Curncy',
    'G0025Z 5Y BLC2 Curncy',
    'G0025Z 10Y BLC2 Curncy'
    ],
'fields':['PX_MID']},
'jpy_rates':{
    'instruments':[
    'G0018Z 3M BLC2 Curncy', #JPY I18 Zero Rate 3M Currncy?
    'G0018Z 6M BLC2 Curncy',
    'G0018Z 1Y BLC2 Curncy',
    'G0018Z 2Y BLC2 Curncy',
    'G0018Z 5Y BLC2 Curncy',
    'G0018Z 10Y BLC2 Curncy',
    ],
'fields':['PX_MID']},
'gbp_rates':{
    'instruments':[
    'G0022Z 3M BLC2 Curncy', #GBP I22 Zero Rate 3M Currncy?
    'G0022Z 6M BLC2 Curncy',
    'G0022Z 1Y BLC2 Curncy',
    'G0022Z 2Y BLC2 Curncy',
    'G0022Z 5Y BLC2 Curncy',
    'G0022Z 10Y BLC2 Curncy',
    ],
'fields':['PX_MID']},
'eur_rates':{
    'instruments':[
    'G0006Z 3M BLC2 Curncy', #EUR I6 Zero Rate 3M Currncy?
    'G0006Z 6M BLC2 Curncy',
    'G0006Z 1Y BLC2 Curncy',
    'G0006Z 2Y BLC2 Curncy',
    'G0006Z 5Y BLC2 Curncy',
    'G0006Z 10Y BLC2 Curncy',
    
    ],
'fields':['PX_MID']
}
}

# %%
API_TASKS.keys()
# Out:
# dict_keys(['us.equities.data', 'uk.equities.data', 'jp.equities.data', 'eu.equities.data', 'us.economics.data', 'jp.economics.data', 'ez.economics.data', 'uk.economics.data', 'gbpusd.option.skew_kurt', 'jpyusd.option.skew_kurt', 'eurusd.option.skew_kurt', 'usd_rates', 'jpy_rates', 'gbp_rates', 'eur_rates'])

# %%
for i in API_TASKS.keys():
    print(API_TASKS[i].keys())
# Out:
# dict_keys(['instruments', 'fields'])
# dict_keys(['instruments', 'fields'])
# dict_keys(['instruments', 'fields'])
# dict_keys(['instruments', 'fields'])
# dict_keys(['instruments', 'fields'])
# dict_keys(['instruments', 'fields'])
# dict_keys(['instruments', 'fields'])
# dict_keys(['instruments', 'fields'])
# dict_keys(['instruments', 'fields'])
# dict_keys(['instruments', 'fields'])
# dict_keys(['instruments', 'fields'])
# dict_keys(['instruments', 'fields'])
# dict_keys(['instruments', 'fields'])
# dict_keys(['instruments', 'fields'])
# dict_keys(['instruments', 'fields'])

# %%
start_date=datetime.date(2000,1,1)
end_date = datetime.date.today()

# %%
all_data = pd.DataFrame()
df = {}

# %%
for k in API_TASKS.keys():
    instrument =API_TASKS[k]['instruments']
    fields = API_TASKS[k]['fields']
    print(k)
    kwargs = {
        'timeout': 1000,
        'allow_missing': True,
    #         'date_columns': {
    #             'date': fix_iso_dates,
    #         },
    #         'post_process': normalize_futures_ticker,
    }
    df[k] = blp.bdh(
            instrument,
            flds=fields,
            start_date=start_date,
            end_date=end_date,
    #             **kwargs,
        )
    all_data=pd.concat([all_data,df[k]],axis=1)
# Out:
# us.equities.data
# uk.equities.data
# jp.equities.data
# eu.equities.data
# us.economics.data
# jp.economics.data
# ez.economics.data
# uk.economics.data
# gbpusd.option.skew_kurt
# jpyusd.option.skew_kurt
# eurusd.option.skew_kurt
# usd_rates
# jpy_rates
# gbp_rates
# eur_rates

# %%
all_data.shape
# Out:
# (6311, 1242)

# %%
'a'+'.csv'
# Out:
# 'a.csv'

# %%
all_data.to_csv('all_data.csv')

# %%
for k in df.keys():
    df[k].to_csv(k+'.csv')
    df[k].to_parquet(k+'.pqt')

# %%
df.keys()
# Out:
# dict_keys(['us.equities.data', 'uk.equities.data', 'jp.equities.data', 'eu.equities.data', 'us.economics.data', 'jp.economics.data', 'ez.economics.data', 'uk.economics.data', 'gbpusd.option.skew_kurt', 'jpyusd.option.skew_kurt', 'eurusd.option.skew_kurt', 'usd_rates', 'jpy_rates', 'gbp_rates', 'eur_rates'])

# %%
len(df.keys())
# Out:
# 15

# %%
pwd
# Out:
# 'H:\\PycharmProjects'

# %%
df['ez.economics.data']
# Out:
# Empty DataFrame
# Columns: []
# Index: []
